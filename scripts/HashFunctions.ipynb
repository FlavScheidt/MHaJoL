# %% [markdown]
# # Runtime

# %%
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker
# from collections import namedtuple

from matplotlib.backends.backend_pdf import PdfPages

width = 0.8
degrees = 45

objects = ('Lookup3','Murmur3','One-at-a-time','Murmur2','FNV1a')
y_pos = np.arange(len(objects))
performance = [37.14285714,19.14285714,18,16,7.142857143]

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(3,2))

plt.bar(y_pos, performance, width, color='grey', align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation=degrees)
plt.ylabel('Runtime [ms]')


plt.savefig('/home/flav/Mestrado/MHaJoL/data/out/plots/runtimeHash.pdf', format='pdf', facecolor='white', edgecolor='none', bbox_inches='tight')
plt.show()
plt.clf()

# %% [markdown]
# # Collision Rate

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker
# from collections import namedtuple

from matplotlib.backends.backend_pdf import PdfPages

width = 0.8
degrees = 45


functions = ('Lookup3','Murmur3','One-at-a-time','Murmur2','FNV1a')
y_pos = np.arange(len(objects))
rate = [27.6593,27.714,27.7213,27.716,23.2213]

plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(3,2))

bar_plot = plt.bar(y_pos, rate, width, color='grey', align='center', alpha=0.5)
plt.xticks(y_pos, objects, rotation=degrees)
plt.ylabel('Collision Rate [%]')

for index, value in enumerate(rate):
    plt.text(index-0.35, value-2.3, str(float(f'{value:.2f}')), fontsize=9)
    
    
#      ax.text(i.get_x()+.12, i.get_height()-3, \
#             str(round((i.get_height()/total)*100, 2))+'%', fontsize=22,
#                 color='white')


plt.savefig('/home/flav/Mestrado/MHaJoL/data/out/plots/collisionHash.pdf', format='pdf', facecolor='white', edgecolor='none', bbox_inches='tight')
plt.show()
plt.clf()
